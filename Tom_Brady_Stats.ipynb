# %%
import pandas as pd
import sqlite3
import numpy as np
import os

#Converts the csv file into a dataframe
QBstats = pd.read_csv('QBStats_all.csv')

QBstats.to_sql('TBstats', sqlite3.connect('nfl_stats.db'), if_exists = "replace")

QBstats.shape
# Out:
# (13188, 14)

# %%
#Contains all statistics from each NFL quarterback from 1996-2016
QBstats
# Out:
#                                    qb  att  cmp    yds   ypa  td int   lg  \
# 0            Boomer EsiasonB. Esiason   38   25  237.0   6.2   0   0   20
# 1             Jim HarbaughJ. Harbaugh   25   16  196.0   7.8   2   1  35t
# 2                Paul JustinP. Justin    8    5   53.0   6.6   0   0   30
# 3                Jeff GeorgeJ. George   35   16  215.0   6.1   0   0   55
# 4             Kerry CollinsK. Collins   31   17  198.0   6.4   2   0   30
# 5                  Jeff BlakeJ. Blake   40   23  226.0   5.7   1   2   46
# 6                 Steve WalshS. Walsh   35   13  154.0   4.4   0   1   32
# 7           Scott MitchellS. Mitchell   41   20  260.0   6.3   1   4   29
# 8                Mark RoyalsM. Royals    1    1   -8.0  -8.0   0   0   -8
# 9              Brad JohnsonB. Johnson   23   16  157.0   6.8   1   0  31t
# 10                 Warren MoonW. Moon   14    5   57.0   4.1   0   0   28
# 11                  Steve BonoS. Bono   37   21  192.0   5.2   2   0   25
# ...

# %%
conn = sqlite3.connect('nfl_stats.db')
pd.read_sql_query('SELECT * FROM TBstats LIMIT 10', conn)
# Out:
#    index                         qb  att  cmp    yds  ypa  td int   lg  sack  \
# 0      0   Boomer EsiasonB. Esiason   38   25  237.0  6.2   0   0   20   2.0
# 1      1    Jim HarbaughJ. Harbaugh   25   16  196.0  7.8   2   1  35t   0.0
# 2      2       Paul JustinP. Justin    8    5   53.0  6.6   0   0   30   1.0
# 3      3       Jeff GeorgeJ. George   35   16  215.0  6.1   0   0   55   7.0
# 4      4    Kerry CollinsK. Collins   31   17  198.0  6.4   2   0   30   4.0
# 5      5         Jeff BlakeJ. Blake   40   23  226.0  5.7   1   2   46   3.0
# 6      6        Steve WalshS. Walsh   35   13  154.0  4.4   0   1   32   2.0
# 7      7  Scott MitchellS. Mitchell   41   20  260.0  6.3   1   4   29   3.0
# 8      8       Mark RoyalsM. Royals    1    1   -8.0 -8.0   0   0   -8   0.0
# 9      9     Brad JohnsonB. Johnson   23   16  157.0  6.8   1   0  31t   1.0
#
#    loss   rate  game_points home_away  year
# 0  11.0   82.9           13      away  1996
# ...

# %%
pd.read_sql_query('SELECT qb, yds, game_points, year FROM TBstats WHERE qb = "Tom Brady"', conn)
# Out:
#             qb    yds  game_points  year
# 0    Tom Brady    6.0            9  2000
# 1    Tom Brady   46.0            3  2001
# 2    Tom Brady  168.0           44  2001
# 3    Tom Brady   86.0           10  2001
# 4    Tom Brady  364.0           29  2001
# 5    Tom Brady  202.0           38  2001
# 6    Tom Brady  203.0           20  2001
# 7    Tom Brady  250.0           24  2001
# 8    Tom Brady  107.0           21  2001
# 9    Tom Brady  185.0           17  2001
# 10   Tom Brady  258.0           34  2001
# 11   Tom Brady  213.0           17  2001
# 12   Tom Brady  218.0           27  2001
# 13   Tom Brady  237.0           12  2001
# 14   Tom Brady  108.0           20  2001
# 15   Tom Brady  198.0           38  2001
# 16   Tom Brady  294.0           30  2002
# 17   Tom Brady  269.0           44  2002
# 18   Tom Brady  410.0           41  2002
# 19   Tom Brady  353.0           14  2002
# 20   Tom Brady  240.0           13  2002
# 21   Tom Brady  183.0           10  2002
# ...

# %% [markdown]
# limit by >150 yards, 150-300, 300+
